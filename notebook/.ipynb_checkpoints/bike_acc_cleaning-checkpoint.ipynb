# %% [markdown]
# ### Load Datasets

# %%
file_path = '../data/raw/ongevallen_2015_2020.csv'
from function_06 import load_data
load_data(file_path)
# Out:
#                             FID    id  totaal  dodelijk  letsel  matrieel  \
# 0        ongevallen_2015_2020.1     1       1         0       1         0
# 1        ongevallen_2015_2020.2     2       1         0       0         1
# 2        ongevallen_2015_2020.3     3       1         0       0         1
# 3        ongevallen_2015_2020.4     4       1         0       1         0
# 4        ongevallen_2015_2020.5     5       2         0       2         0
# ...                         ...   ...     ...       ...     ...       ...
# 1796  ongevallen_2015_2020.1797  1797       1         0       0         1
# 1797  ongevallen_2015_2020.1798  1798       1         0       1         0
# 1798  ongevallen_2015_2020.1799  1799       1         0       1         0
# 1799  ongevallen_2015_2020.1800  1800       1         0       0         1
# 1800  ongevallen_2015_2020.1801  1801       1         0       1         0
#
#       gdb_geomattr_data                                              shape
# ...

# %%
import pandas as pd
df2=pd.read_excel('../data/raw/dataset/utrecht-fietstellingen-2016-totaal.xlsx')
df2
# Out:
#      Unnamed: 0                              Unnamed: 1  \
# 0           NaN             Fietstellingen Utrecht 2016
# 1           NaN                             Indicatoren
# 2           NaN                                     NaN
# 3           NaN  Gemiddelden over representatieve dagen
# 4           NaN                                     NaN
# ..          ...                                     ...
# 118         NaN                                       7
# 119         NaN                                       8
# 120         NaN                                       9
# 121         NaN                                      10
# 122         NaN                                      11
#
#                 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                      NaN                 NaN        NaN        NaN
# 1                      NaN                 NaN        NaN        NaN
# 2                      NaN                 NaN        NaN        NaN
# ...
